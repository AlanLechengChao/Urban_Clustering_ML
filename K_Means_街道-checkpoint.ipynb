# %%
# ! pip install geopandas
from sklearn.cluster import KMeans
from sklearn.cluster import AffinityPropagation 
from sklearn.mixture import GaussianMixture
from sklearn import preprocessing
from sklearn.cluster import DBSCAN
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import io

# from google.colab import files
# uploaded = files.upload()

df = pd.read_excel("POI_Fishnet_for_training.xls",usecols=[1,2,3,4])
columns = list(df.columns)
df = df.fillna(0)
values = df.values
min_max_scaler = preprocessing.MinMaxScaler()
values_scaled = min_max_scaler.fit_transform(values)
df = pd.DataFrame(values_scaled, columns=columns)
df
# Out:
#        加权合计POI      人口密度  商铺人均消费        房价
# 0     0.000000  0.043875     0.0  0.000000
# 1     0.000938  0.043875     0.0  0.000000
# 2     0.000000  0.043875     0.0  0.000000
# 3     0.000000  0.043875     0.0  0.000000
# 4     0.000501  0.043875     0.0  0.000000
# ...        ...       ...     ...       ...
# 2910  0.001289  0.022057     0.0  0.000000
# 2911  0.001948  0.022057     0.0  0.034483
# 2912  0.000000  0.022057     0.0  0.000000
# 2913  0.000000  0.022057     0.0  0.000000
# 2914  0.000215  0.022057     0.0  0.000000
#
# [2915 rows x 4 columns]

# %%
kmeans = KMeans(n_clusters=6, random_state=0, n_init=6)
kmeans.fit(df)

GM=GaussianMixture(n_components=6)
GM.fit(df)

# AP = AffinityPropagation()
# AP.fit(df)

db=DBSCAN(eps=0.2,min_samples=2).fit(df)
# a=set(db.labels_)
# print(a)

# %%
#print(kmeans.labels_)

df['GaussianMixture_result'] = GM.predict(df)
df['Kmeans_result'] = kmeans.labels_
# df['AffinityPropagation_result'] = AP.labels_
df['db_result']=db.labels_

# %%
plt.figure()
df.plot.scatter(x='加权合计POI', y='人口密度',
                     c='Kmeans_result', cmap=plt.get_cmap('jet'), colorbar=False, title='k means, 6 clusters')
# Out:
# <AxesSubplot:title={'center':'k means, 6 clusters'}, xlabel='加权合计POI', ylabel='人口密度'>
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 26435 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 35745 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21475 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 23494 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24230 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 26435 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 35745 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 21475 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 23494 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/chaolecheng/Library/Python/3.8/lib/python/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 24230 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# 功能区：
# * 底图 - 市政府
# * 指数：Diversity Index - benchmark: 混合 / 某一类
# * 3种machine learning model 解释3种model为什么不一样

# %%
# from google.colab import files
# uploaded = files.upload()
shanghai_fishnet = gpd.read_file('fishnet4900_shanghai.shp')
# shanghai_fishnet.head
joined_by_fishnet = shanghai_fishnet.join(df) #.set_index('k_index')
print(joined_by_fishnet)

joined_by_fishnet.plot(cmap=plt.get_cmap('jet'), column='Kmeans_result', figsize=(10,10))
plt.title('K-Means, 6 clusters')
plt.show()
joined_by_fishnet.plot(cmap=plt.get_cmap(
    'jet'), column='GaussianMixture_result', figsize=(10, 10))
plt.title('Gaussian Mixture, 6 clusters')

# joined_by_fishnet.plot(cmap=plt.get_cmap(
#     'jet'), column='AffinityPropagation_result', figsize=(10, 10))
# plt.title('AffinityPropagation')

joined_by_fishnet.plot(cmap=plt.get_cmap(
    'jet'), column='db_result', figsize=(10, 10))
plt.title(f'DBSCAN eps={db.eps} min_points={db.min_samples}')
plt.show()
# Out:
#                                                geometry   加权合计POI      人口密度  \
# 0     POLYGON ((13498006.072 3592692.406, 13498006.0...  0.000000  0.043875
# 1     POLYGON ((13499783.695 3592692.406, 13499783.6...  0.000938  0.043875
# 2     POLYGON ((13501561.317 3592692.406, 13501561.3...  0.000000  0.043875
# 3     POLYGON ((13503338.940 3592692.406, 13503338.9...  0.000000  0.043875
# 4     POLYGON ((13505116.562 3592692.406, 13505116.5...  0.000501  0.043875
# ...                                                 ...       ...       ...
# 2910  POLYGON ((13503338.940 3697030.642, 13503338.9...  0.001289  0.022057
# 2911  POLYGON ((13505116.562 3697030.642, 13505116.5...  0.001948  0.022057
# 2912  POLYGON ((13506894.184 3697030.642, 13506894.1...  0.000000  0.022057
# 2913  POLYGON ((13508671.807 3697030.642, 13508671.8...  0.000000  0.022057
# 2914  POLYGON ((13510449.429 3697030.642, 13510449.4...  0.000215  0.022057
#
#       商铺人均消费        房价  GaussianMixture_result  Kmeans_result  db_result
# 0        0.0  0.000000                       0              3          0
# 1        0.0  0.000000                       0              3          0
# 2        0.0  0.000000                       0              3          0
# 3        0.0  0.000000                       0              3          0
# 4        0.0  0.000000                       0              3          0
# ...      ...       ...                     ...            ...        ...
# 2910     0.0  0.000000                       0              3          0
# 2911     0.0  0.034483                       5              5          1
# 2912     0.0  0.000000                       0              3          0
# 2913     0.0  0.000000                       0              3          0
# 2914     0.0  0.000000                       0              3          0
#
# [2915 rows x 8 columns]
